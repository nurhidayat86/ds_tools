# %% [markdown]
# # Input necessary package

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Input data

# %%
data = pd.read_csv("D:\Download\TONGDUN_FEAT_STATIC.csv")
# Out:
# C:\Users\Arif\Anaconda3\envs\ds_env\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Metadata definition

# %%
col_idex = 'SKP_CREDIT_CASE'
col_obs = 'FPD30_OBS'
col_target = 'FPD30_CNT'
col_time = 'DATE_DECISION'
col_month = 'MONTH'
col_day = 'DAY'
col_index = 'SKP_CREDIT_CASE'

# %%
data['DATE_DECISION'] = pd.to_datetime(data['DATE_DECISION'], format='%Y-%m-%d')

# %%
data[col_month] = data[col_time].dt.strftime('%Y%m').astype('int')
data[col_day] = data[col_time].dt.strftime('%Y%m%d').astype('int')

# %%
data.head()
# Out:
#    SKP_CREDIT_CASE                            TONGDUN_ID  USER_ID_GOJEK  \
# 0         73517784  c053415b-657a-496f-b149-692763836548   8.387182e+10
# 1         73524496  8c08b7f6-cb30-44ad-a601-804b23d8e192            NaN
# 2         73573320  64fae998-fbaa-4549-b0b4-a74d11b62b7d            NaN
# 3         73577867  e6fd1485-49f7-45d0-a454-5559ec954022            NaN
# 4         73626163  92133139-40d8-4961-949b-c17fd04f201e            NaN
#
#    USER_ID_GRAB  USER_ID_TOKOPEDIA       TONGDUN_SENT_DTIME  \
# 0           NaN                NaN  2019-04-18 17:13:37.087
# 1           NaN                NaN  2019-04-30 21:00:40.305
# 2           NaN                NaN  2019-04-26 00:03:29.234
# 3           NaN                NaN  2019-06-08 05:08:46.731
# 4           NaN                NaN  2019-06-30 12:37:25.607
#
#    SKP_CREDIT_CASE.1  SKP_CLIENT        PHONE DATE_DECISION  ...  \
# 0           73517784       93307  83871822935    2019-04-01  ...
# ...

# %%
for i in data.columns:
    print(f'{i}: {data[i].dtypes}')
# Out:
# SKP_CREDIT_CASE: int64
# TONGDUN_ID: object
# USER_ID_GOJEK: float64
# USER_ID_GRAB: float64
# USER_ID_TOKOPEDIA: float64
# TONGDUN_SENT_DTIME: object
# SKP_CREDIT_CASE.1: int64
# SKP_CLIENT: int64
# PHONE: int64
# DATE_DECISION: object
# MON_DEC: object
# CODE_CLIENT_TYPE: object
# CODE_PRODUCT_PROFILE: object
# NAME_CREDIT_STATUS_APP: object
# AMT_CREDIT_TOTAL: float64
# TICKET: object
# CNT_INSTALMENT: int64
# TENURE: object
# FPD10_CNT: int64
# FPD10_OBS: int64
# FPD30_CNT: int64
# FPD30_OBS: int64
# TOP_AVG_TRANSC_TOTAL: float64
# TOP_AVG_TRANSC_SHIPPING: float64
# TOP_AVG_TRANSC_INSURANCE: float64
# TOP_MAX_TRANSC_SHIPPING: float64
# TOP_MAX_TRANSC_INSURANCE: float64
# TOP_MAX_TRANSC_TOTAL: float64
# TOP_TOTAL_USE_INSURANCE: float64
# TOP_SALDO: float64
# TOP_TOKOCASH: float64
# TOP_TOTAL_BUY_GOLDSTORE: float64
# TOP_TOTAL_BUY_OFFCSTORE: float64
# TOP_TOTAL_CART_HANDPHONE: float64
# TOP_TOTAL_CART_ELECTRIC: float64
# TOP_TOTAL_CART_COMPUTER: float64
# ...

# %%
print(f"Data before duplicates are removed: {data.shape}")
data.index = data[col_index]
data = data.drop_duplicates(subset=col_index)
print(f"data after duplicates are removed: {data.shape}")
# Out:
# Data before duplicates are removed: (606959, 127)
# data after duplicates are removed: (606959, 127)

# %%
data
# Out:
#                  SKP_CREDIT_CASE                            TONGDUN_ID  \
# SKP_CREDIT_CASE
# 73517784                73517784  c053415b-657a-496f-b149-692763836548
# 73524496                73524496  8c08b7f6-cb30-44ad-a601-804b23d8e192
# 73573320                73573320  64fae998-fbaa-4549-b0b4-a74d11b62b7d
# 73577867                73577867  e6fd1485-49f7-45d0-a454-5559ec954022
# 73626163                73626163  92133139-40d8-4961-949b-c17fd04f201e
# ...                          ...                                   ...
# 87439245                87439245  d2e31607-053c-48ed-af0d-8ec55e742e7e
# 87439407                87439407  c3e5c947-1020-46ce-ab2b-5969d3300c6e
# 87440158                87440158  def70501-bd84-48bf-88df-6f78f31738d9
# 87440697                87440697  3ffd4657-c07c-4f37-a925-32ba5272ae61
# 87440794                87440794  1dd1d3cb-af38-481b-8fae-230a9ca5b578
#
#                  USER_ID_GOJEK  USER_ID_GRAB  USER_ID_TOKOPEDIA  \
# SKP_CREDIT_CASE
# ...
